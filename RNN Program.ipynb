# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (26.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (2.2.6)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\envs\tf_env\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/HP/OneDrive/Desktop/spam.csv", encoding='latin-1')

# %%
df = df[['v1','v2']]
df.columns = ['label','message']

# %%
print(df.head())
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df['label'] = df['label'].map({'ham':0, 'spam':1})

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['message'])

X = tokenizer.texts_to_sequences(df['message'])
X = pad_sequences(X, maxlen=100)

y = df['label']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential([
    Embedding(input_dim=5000, output_dim=64),
    LSTM(64),
    Dense(1, activation='sigmoid')
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=5)

model.summary()
# Out:
# Epoch 1/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9478 - loss: 0.1627
# Epoch 2/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.9903 - loss: 0.0359
# Epoch 3/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9964 - loss: 0.0172
# Epoch 4/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9980 - loss: 0.0079
# Epoch 5/5
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9987 - loss: 0.0052
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 100, 64)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,059,269 (4.04 MB)
#  Trainable params: 353,089 (1.35 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 706,180 (2.69 MB)

# %%
model.save("spam_model.keras")

# %%
import joblib
joblib.dump(tokenizer, "tokenizer.joblib")
# Out:
# ['tokenizer.joblib']

# %%
model.save("spam_model.keras")
